# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# **Carolina Pantuza Vilar dos Santos**
#
# Professor

# %% [markdown]
# *I am interested in data science because I am extremely curious and research is part of my life as a researcher and teacher. Surely this skill will help me a lot.

# %% [markdown]
# ### My code should perform a simple sum (1+1).

# %%
1+1
# Out:
# 2

# %% [markdown]
# ###### Carolina's contacts
#
# | Professional | Academic |
# | ------ | ------ |
# | https://www.linkedin.com/in/carolina-pantuza-b0865539/ | https://orcid.org/0000-0001-9996-8262|
#
# ###### You can get in touch for:
#
# 1. exchange knowledge about data science
# 2. discuss about social marketing
# 3. talk about projects about mindfulness
# 4. designing research for societal well-being
